# %%
pip install import-ipynb
# Out:
# Requirement already satisfied: import-ipynb in /Users/jagxsira/opt/anaconda3/lib/python3.9/site-packages (0.1.4)
# Requirement already satisfied: IPython in /Users/jagxsira/opt/anaconda3/lib/python3.9/site-packages (from import-ipynb) (8.2.0)
# Requirement already satisfied: nbformat in /Users/jagxsira/opt/anaconda3/lib/python3.9/site-packages (from import-ipynb) (5.3.0)
# Requirement already satisfied: stack-data in /Users/jagxsira/opt/anaconda3/lib/python3.9/site-packages (from IPython->import-ipynb) (0.2.0)
# Requirement already satisfied: setuptools>=18.5 in /Users/jagxsira/opt/anaconda3/lib/python3.9/site-packages (from IPython->import-ipynb) (61.2.0)
# Requirement already satisfied: traitlets>=5 in /Users/jagxsira/opt/anaconda3/lib/python3.9/site-packages (from IPython->import-ipynb) (5.1.1)
# Requirement already satisfied: matplotlib-inline in /Users/jagxsira/opt/anaconda3/lib/python3.9/site-packages (from IPython->import-ipynb) (0.1.2)
# Requirement already satisfied: pygments>=2.4.0 in /Users/jagxsira/opt/anaconda3/lib/python3.9/site-packages (from IPython->import-ipynb) (2.11.2)
# Requirement already satisfied: jedi>=0.16 in /Users/jagxsira/opt/anaconda3/lib/python3.9/site-packages (from IPython->import-ipynb) (0.18.1)
# Requirement already satisfied: decorator in /Users/jagxsira/opt/anaconda3/lib/python3.9/site-packages (from IPython->import-ipynb) (5.1.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /Users/jagxsira/opt/anaconda3/lib/python3.9/site-packages (from IPython->import-ipynb) (3.0.20)
# Requirement already satisfied: pexpect>4.3 in /Users/jagxsira/opt/anaconda3/lib/python3.9/site-packages (from IPython->import-ipynb) (4.8.0)
# Requirement already satisfied: backcall in /Users/jagxsira/opt/anaconda3/lib/python3.9/site-packages (from IPython->import-ipynb) (0.2.0)
# Requirement already satisfied: appnope in /Users/jagxsira/opt/anaconda3/lib/python3.9/site-packages (from IPython->import-ipynb) (0.1.2)
# Requirement already satisfied: pickleshare in /Users/jagxsira/opt/anaconda3/lib/python3.9/site-packages (from IPython->import-ipynb) (0.7.5)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/jagxsira/opt/anaconda3/lib/python3.9/site-packages (from jedi>=0.16->IPython->import-ipynb) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /Users/jagxsira/opt/anaconda3/lib/python3.9/site-packages (from pexpect>4.3->IPython->import-ipynb) (0.7.0)
# Requirement already satisfied: wcwidth in /Users/jagxsira/opt/anaconda3/lib/python3.9/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->IPython->import-ipynb) (0.2.5)
# Requirement already satisfied: jupyter-core in /Users/jagxsira/opt/anaconda3/lib/python3.9/site-packages (from nbformat->import-ipynb) (4.9.2)
# Requirement already satisfied: fastjsonschema in /Users/jagxsira/opt/anaconda3/lib/python3.9/site-packages (from nbformat->import-ipynb) (2.15.1)
# Requirement already satisfied: jsonschema>=2.6 in /Users/jagxsira/opt/anaconda3/lib/python3.9/site-packages (from nbformat->import-ipynb) (4.4.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/jagxsira/opt/anaconda3/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat->import-ipynb) (0.18.0)
# Requirement already satisfied: attrs>=17.4.0 in /Users/jagxsira/opt/anaconda3/lib/python3.9/site-packages (from jsonschema>=2.6->nbformat->import-ipynb) (21.4.0)
# Requirement already satisfied: asttokens in /Users/jagxsira/opt/anaconda3/lib/python3.9/site-packages (from stack-data->IPython->import-ipynb) (2.0.5)
# Requirement already satisfied: pure-eval in /Users/jagxsira/opt/anaconda3/lib/python3.9/site-packages (from stack-data->IPython->import-ipynb) (0.2.2)
# Requirement already satisfied: executing in /Users/jagxsira/opt/anaconda3/lib/python3.9/site-packages (from stack-data->IPython->import-ipynb) (0.8.3)
# Requirement already satisfied: six in /Users/jagxsira/opt/anaconda3/lib/python3.9/site-packages (from asttokens->stack-data->IPython->import-ipynb) (1.16.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
# import packages

import scipy.io as sio  # for loading matlab data

import numpy as np      # for numerical libs

from matplotlib.ticker import FuncFormatter # for custom bar plot labels

import matplotlib.pyplot as plt  # for plotting

import matplotlib.pylab as pylab
params = {'legend.fontsize': 'x-large',
          'figure.figsize': (15, 5),
         'axes.labelsize': 'x-large',
         'axes.titlesize':'x-large',
         'xtick.labelsize':'x-large',
         'ytick.labelsize':'x-large'}
pylab.rcParams.update(params)

import pandas as pd

# %%
data = sio.loadmat('FB_20141103.mat')

# %%
LOB=data['LOB']

t = (np.array((LOB['EventTime'][0][0][:,0]))-3600000*9.5)*1e-3
bid = np.array(LOB['BuyPrice'][0][0]*1e-4)
bidvol = np.array(LOB['BuyVolume'][0][0]*1.0)
ask = np.array(LOB['SellPrice'][0][0]*1e-4)
askvol = np.array(LOB['SellVolume'][0][0]*1.0)
MO=np.array(LOB['MO'][0][0]*1.0)
dt = t[1]-t[0]

# %%
midprice = 0.5*(bid[:,0]+ask[:,0])
microprice= (bid[:,0]*askvol[:,0]+ask[:,0]*bidvol[:,0])/(bidvol[:,0]+askvol[:,0])
spread = ask[:,0]-bid[:,0]

# %%
plt.plot(t, microprice)
plt.title('Microprice')
plt.ylabel('price')
plt.xlabel('time (seconds from trading start)')
plt.show()

# %%
plt.plot(t, microprice-midprice)
plt.title('Microprice - Midprice')
plt.ylabel('diff')
plt.xlabel('time (seconds from trading start)')
plt.show()

# %%
plt.plot(t,spread)
plt.title('Spread')
plt.ylabel('spread')
plt.xlabel('time (seconds from trading start)')
plt.show()

# %%
plt.hist(spread,bins=[0.01,0.02,0.03], width=0.001,align='mid') 
plt.title("Hist of spread")
plt.xlabel(r'spread')
plt.ylabel('Freq')
plt.show()

# %%
n = np.random.standard_normal((9,4))
n
# Out:
# array([[-1.15278771, -1.21806093,  0.27422578, -0.60894786],
#        [ 1.05008058,  0.87193482, -0.17611557, -0.03396403],
#        [ 2.21170005,  0.20881454, -0.33348229, -0.63046256],
#        [ 0.5708269 , -0.20594576, -1.49264779, -0.38755304],
#        [ 1.7276318 , -0.90391204, -1.35226094, -0.89529828],
#        [ 0.58906936,  0.54558379,  0.67572154, -2.34722111],
#        [ 0.09583506, -0.39196935, -1.46729012,  0.45667714],
#        [ 0.80456806, -0.26814954,  1.03499263,  0.60766083],
#        [-0.59460073, -1.42303516,  0.35821825, -1.93831243]])

# %%
df = pd.DataFrame(midprice)
df.describe()
# Out:
#                    0
# count  234000.000000
# mean       74.392926
# std         0.476106
# min        73.705000
# 25%        73.965000
# 50%        74.195000
# 75%        74.925000
# max        75.515000

# %%
df = pd.DataFrame(microprice)
df.describe()
# Out:
#                    0
# count  234000.000000
# mean       74.392551
# std         0.475853
# min        73.708022
# 25%        73.965633
# 50%        74.190614
# 75%        74.920594
# max        75.513571

# %%
df = pd.DataFrame(spread)
df.describe()
# Out:
#                    0
# count  234000.000000
# mean        0.010953
# std         0.003337
# min         0.010000
# 25%         0.010000
# 50%         0.010000
# 75%         0.010000
# max         0.070000

# %%
rho = np.array((bidvol[:,0]-askvol[:,0])/(bidvol[:,0]+askvol[:,0]),ndmin=2).T

# %%
plt.plot(t, rho)
plt.title('Imbalance')
plt.ylabel(r'$\rho$')
plt.xlabel('time (seconds from trading start)')

a = plt.axes([.65, .6, .2, .2])
idx = (t>3600) & (t<=3600+60)
plt.plot( t[idx], rho[idx])
plt.title('a')
plt.ylabel(r'$\rho$')
plt.xlabel(r'$t$')
plt.xticks([3600,3630,3660])

plt.show()

# %%
plt.acorr(rho[:,0]-np.mean(rho[:,0]),maxlags=6000)  # maximum one minute 
plt.title('Autocorrelation of imbalance')
plt.xlim([0,6000])
plt.show()

# %%
plt.hist(rho, bins=np.linspace(-1, 1, num=50)) 
plt.title("Hist of imbalance")
plt.xlabel(r'$\rho$')
plt.ylabel('Freq')
plt.show()

# %%
rho_MO = (MO[:,3]-MO[:,4])/(MO[:,3]+MO[:,4])

# %%
plt.hist(rho_MO[MO[:,7]==-1], bins=np.linspace(-1, 1, num=10),alpha=0.5)
plt.hist(rho_MO[MO[:,7]==+1], bins=np.linspace(-1, 1, num=10),alpha=0.5)
plt.title("Hist of imbalance conditional on MO type")
plt.xlabel(r'$\rho$')
plt.ylabel('Freq')
plt.show()

# %%
# Import necessary libraries.
import numpy as np
import import_ipynb
import Liquidation_Permanent_Price_Impact_helper as lppi_helpers
# Out:
# importing Jupyter notebook from Liquidation_Permanent_Price_Impact_helper.ipynb

# %%
# Parameter settings
T = 1
Ndt = 6.5 * 3600
dt = T / Ndt
t = np.arange(0, T + dt, dt)

k = 0.002
b = 0.003

tau = T - t
tt = np.arange(0, 1 + 1 / 10, 1 / 10)

myphi = np.array([10e-10, 0.001, 0.01, 0.1])
symb = np.array(["o", "*", "+", "^"])

alpha = 100

# %%
# Fig 6.2 of Page 148
lppi_helpers.plot_inventory_trading_speed(0.01, myphi, symb, t, tt, T, b, k, [r"$\phi = $" + str(i) for i in myphi], main=r"$\alpha = 0.01$")
lppi_helpers.plot_inventory_trading_speed(100, myphi, symb, t, tt, T, b, k, [r"$\phi = $" + str(i) for i in myphi], main=r"$\alpha = +\infty$")
